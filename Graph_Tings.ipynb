# %%
from scipy import *
from pylab import *

graph = {'A': ['B', 'C'],
         'B': ['C', 'D'],
         'C': ['D'],
         'D': ['C'],
         'E': ['F'],
         'F': ['C']}

print(graph)
# Out:
# {'C': ['D'], 'E': ['F'], 'D': ['C'], 'F': ['C'], 'A': ['B', 'C'], 'B': ['C', 'D']}

# %%
def find_path(graph, start, end, path=[]):
    path = path + [start]
    if start == end:
        return path
    if start not in graph:
        return None
    for node in graph[start]:
        if node not in path:
            newpath = find_path(graph, node, end, path)
            if newpath: return newpath
    return None

find_path(graph, 'A', 'D')
# Out:
# ['A', 'B', 'C', 'D']

# %%
def find_all_paths(graph, start, end, path=[]):
        path = path + [start]
        if start == end:
            return [path]
        if start not in graph:
            return []
        paths = []
        for node in graph[start]:
            if node not in path:
                newpaths = find_all_paths(graph, node, end, path)
                for newpath in newpaths:
                    paths.append(newpath)
        return paths
    
find_all_paths(graph, 'A', 'D')
# Out:
# [['A', 'B', 'C', 'D'], ['A', 'B', 'D'], ['A', 'C', 'D']]

# %%
num_points = 150
Tx = linspace(5., 8., num_points)
Ty = Tx

tX = 11.86*cos(2*pi/0.81*Tx-1.32) + 0.64*Tx+4*((0.5-rand(num_points))*exp(2*rand(num_points)**2))
tY = -32.14*cos(2*pi/0.8*Ty-1.94) + 0.15*Ty+7*((0.5-rand(num_points))*exp(2*rand(num_points)**2))

print(tX, tY)
# Out:
# [ 12.97598995  14.37876635  19.22289981  14.21142224  11.4394593
#   11.7394627   13.05986566  14.84483707  10.79115709   2.88995205
#    8.17038469   4.00599277   2.91613529  -2.32935265  -3.95975434
#   -4.64566342  -6.78640958  -2.22974675  -3.17016419 -10.27895396
#   -5.71815131 -12.88148598  -4.82061406   4.97106619  -8.06549839
#   -9.99799257  -7.55091221  -6.75256206  -2.613472    -3.0708927
#    3.14487446   2.58236286   2.20091925   5.65002557   5.36942692
#   15.33894325  14.67633651  15.09108117  12.17536469  15.21940069
#   15.91332681  17.55631961  15.25642953  19.43698034  12.58469202
#   15.35654885  11.59357975  13.09149876   3.95356242   9.08438813
#    0.61749451   4.30454735   3.89889103   1.10985267  -0.17831115
#   -0.29133089  -3.2295836   -4.99746459  -4.52769198  -7.78455814
#   -6.22355735  -4.60634042 -17.37299302 -11.50593251  -9.07887311
#   -5.53093018  -4.95022548  -6.15162788   0.38164445  -0.66181325
#   -0.05764138   1.6741637    6.90355547   3.72744451  10.15818054
#    3.42699551  12.97681482  15.49781261  15.82818941  15.80846086
#   16.92836607  20.82761063  16.81807987  16.97441174   9.74385826
#   15.98688838  15.04298564   8.11592234  15.64315324  20.89186619
#    8.89300348  12.63517232   3.72869572   1.75197206   5.54091318
#   -5.1172467   -4.01064222  -3.87674891  -5.48568413  -0.80650895
